# %%
import datetime              as dt
import numpy                 as np
import pandas                as pd
import matplotlib.pyplot     as plt
import seaborn               as sns

# %%
df = pd.read_csv('../ETL/data/product_info.csv')
df.head(5)
# Out:
#              gtin part_number     canonical_sku seller_product_sku  \
# 0   3147980006664         NaN  PRD0EONXV0VOE9X2   PRDDIZQ5LTN0FXAN
# 1   7908217006606         NaN  PRDDYFF1LNJ28DL6   PRD4JLE5JYI8RW5Z
# 2   7891638005016         NaN  PRDX5FJSTR3ELOH1   PRDZFI1Y1WL9LUKG
# 3   7896576405898         NaN  PRDRCEHVFJ83YECI   PRD8D1N0DGH1QO68
# 4  78911904694596         NaN  PRD0WIEV4V2NHZHA   PRDP1X3NSSEPUPMS
#
#                                                 name  \
# 0                 Adaptador de tomadas para veicular
# 1  Mini Mesa Pebolim Grande Totó Futebol 18 Jogad...
# 2      Jogo De Chave Biela 11 Peças 8 A 19Mm Starfer
# 3       Aquecedor Digital Gas 21L REUE210FEHB Rinnai
# 4                  Campainha Sirene Relogio De Ponto
#
#                                          description    external_id  \
# 0  Especificações:\n- Tamanho reduzido;\n- Bi-vol...       42096029
# 1  Jogo Mini Bilhar Sinuca Snooker em Madeira\n \...            NaN
# ...

# %%
df.shape
# Out:
# (6518, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6518 entries, 0 to 6517
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   gtin                6518 non-null   int64
#  1   part_number         156 non-null    object
#  2   canonical_sku       6518 non-null   object
#  3   seller_product_sku  6518 non-null   object
#  4   name                6518 non-null   object
#  5   description         6518 non-null   object
#  6   external_id         2611 non-null   object
#  7   channel_slug        6518 non-null   object
#  8   price               6518 non-null   float64
#  9   offer               6518 non-null   float64
#  10  stock               6518 non-null   int64
#  11  created_at          6518 non-null   object
#  12  updated_at          6518 non-null   object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 662.1+ KB

# %%
df.describe()
# Out:
#                gtin          price          offer          stock
# count  6.518000e+03    6518.000000    6518.000000    6518.000000
# mean   7.330889e+12     270.765344     246.032274     608.853176
# std    3.992222e+12    1309.464733    1299.147481    8566.917080
# min    1.789851e+11       6.990000       6.990000       0.000000
# 25%    7.804321e+12      74.925000      62.925000       5.000000
# 50%    7.897313e+12     149.900000     130.890000       5.000000
# 75%    7.899058e+12     285.115000     244.960000      26.000000
# max    7.891190e+13  100000.000000  100000.000000  246212.000000
