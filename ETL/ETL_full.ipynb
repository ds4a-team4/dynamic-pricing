# %% [markdown]
# # Dataframe for Dynamic Pricing

# %% [markdown]
# ## Objectives
#
# This document intends to briefly describe one alternative for the ETL process for the Dynamic Pricing problem at Olist.
# As the end product, we would like to have a table with the proper structure for forecasting techniques.
# The datasets will be described along the way.

# %% [markdown]
# ### Importing packages

# %%
import pandas as pd
import datetime

# %% [markdown]
# # Experimentation: Loops

# %% [markdown]
# ### 1 - Read dataframes

# %%
# ORDERS
orders = pd.read_csv('data/orders.csv', dtype={'product_gtin':'str','origin_zip':'str','destination_zip':'str'})
orders['purchase_timestamp'] = pd.to_datetime(orders['purchase_timestamp'])

# PRODUCT INFO
prod_info = pd.read_csv('data/product_info.csv', dtype={'gtin':'str'})
prod_info['created_at'] = pd.to_datetime(prod_info['created_at'])

# PRODUCT TYPE
product_type = pd.read_csv('data/product_type.csv', dtype={'value':str})

# PRODUCT HISTORY
history = pd.read_csv('data/full_history.csv', dtype={'gtin':str})
history['updated_at'] = pd.to_datetime(history['updated_at'])

# COMPETITION
competition = pd.read_csv('data/competition.csv', dtype={'gtin':'str'})
competition['updated_at'] = pd.to_datetime(competition['updated_at'])

# TODO PRODUCTS WITHOUT SALES
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (0,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### 2 - CREATE BASIC ETL

# %%
#orders.product_gtin.value_counts()

# %%
gtin = '7898164712364'

# Get creation date for selected gtin
created_at = prod_info[prod_info['gtin']==gtin]['created_at'].min().date()

name = prod_info[prod_info['gtin']==gtin]['name'].iloc[0]
description = prod_info[prod_info['gtin']==gtin]['description'].iloc[0]


# Create full range df from creation date to today
freq = 'D'
end_date = '2020-04-05'
t_df = pd.DataFrame(data=pd.date_range(start=created_at, end=end_date, freq=freq), columns=['date'])


## ORDERS DATASET
# Filter orders dataset
t_orders = orders[orders['product_gtin']==gtin][['purchase_timestamp','product_gtin', 'price','freight_value', 'commission_product_olist','commission_freight_olist']].copy()

# ADD ARTIFICIAL COLUMN WITH THE NUMBER OF ORDERS -> WILL BE USED TO COUNT THE ORDERS BY HOUR
t_orders['orders'] = 1


# GROUPS ORDERS BY CHOSEN FREQUENCY
t_orders = t_orders.groupby([pd.Grouper(key='purchase_timestamp', freq=freq),'product_gtin'])\
                  .agg({'price':'mean', 
                        'freight_value':'mean',
                        'commission_product_olist':'mean',
                        'commission_freight_olist':'mean',
                        'orders':'sum'}).reset_index()

# MERGE
t_df = pd.merge(t_df, t_orders, how='left', left_on='date', right_on='purchase_timestamp')
t_df.drop('purchase_timestamp', axis=1, inplace=True)
t_df['product_gtin'] = gtin


# ## COMPETITION DATASET
# # FILTER GTIN
t_competition = competition[competition['gtin'] == gtin].copy()
# Exclude 0 values
t_competition = t_competition[t_competition['value']>0]
# filter competition on extremely low and high prices
std = t_competition['value'].std()
mean = t_competition['value'].mean()
t_competition = t_competition[(t_competition['value']>= mean-3*std) & (t_competition['value']<= mean+3*std)]

# Group by freq and get minimum value
t_competition = t_competition.groupby([pd.Grouper(key='updated_at', freq=freq),'gtin']).min()[['value']].reset_index()

# Merge datasets
t_df = pd.merge(t_df, t_competition,
         left_on=['date','product_gtin'], right_on=['updated_at', 'gtin'],
         how='left')

t_df.rename(columns={'value':'competition_price'}, inplace=True)

t_df = t_df[['date', 'product_gtin', 'competition_price', 'price', 'freight_value',
       'commission_product_olist', 'commission_freight_olist', 'orders']].copy()

t_df['competition_price'].fillna(method='ffill', inplace=True)
t_df['competition_price'].fillna(method='bfill', inplace=True)


# # PRODUCT TYPE DATASET
t_product_type = product_type[product_type['value']==gtin].copy()

t_df = pd.merge(left=t_df, right=t_product_type,
         left_on='product_gtin', right_on='value', how='left')[['date', 'product_gtin', 'competition_price',
                                                    'price', 'freight_value', 'commission_product_olist', 
                                                    'commission_freight_olist', 'orders','product_type', 
                                                    'product_type_group']]




# # HISTORY DATASET
t_history = history[history['part_number']==gtin].copy()

t_history.head()

# # filter zero and outlier values
# t_history = t_history[t_history['offer'] > 0].copy()
# std = t_history['offer'].std()
# mean = t_history['offer'].mean()

# t_history = t_history[(t_history['offer']>= mean-3*std) & (t_history['offer']<= mean+3*std)]

# t_history = t_history.groupby([pd.Grouper(key='updated_at', freq='D'), 'gtin'])\
#                          .agg({'stock':['max', 'min', 'mean'], 
#                                'price':['max', 'min', 'mean'],
#                                'offer':['max', 'min', 'mean']}).reset_index()

# t_history.columns = t_history.columns.droplevel(0)

# t_history.columns = ['date', 'product_gtin',
#                    'stock_max', 'stock_min', 'stock_avg',
#                    'price_max','price_min','price_avg',
#                    'offer_max','offer_min','offer_avg']

# t_df = pd.merge(left=t_df, right=t_history,
#                   left_on=['date', 'product_gtin'], right_on=['date', 'product_gtin'],
#                   how='left')

# # forward fill agg measures then backfill
# t_df[['stock_max', 'stock_min',
#        'stock_avg', 'price_max', 'price_min', 'price_avg', 'offer_max',
#        'offer_min', 'offer_avg']] = t_df[['stock_max', 'stock_min',
#                                             'stock_avg', 'price_max', 'price_min', 'price_avg', 'offer_max',
#                                             'offer_min', 'offer_avg']]\
#                                             .fillna(method='pad')\
#                                             .fillna(method='bfill')

# t_df['name'] = name
# t_df['description'] = description
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# Empty DataFrame
# Columns: [gtin, part_number, canonical_sku, seller_product_sku, channel_slug, external_id, price, offer, stock, updated_at]
# Index: []

# %%
def etl_function(gtin, orders, prod_info, product_type, competition, history):
    # Get creation date for selected gtin
    created_at = prod_info[prod_info['gtin']==gtin]['created_at'].min().date()

    name = prod_info[prod_info['gtin']==gtin]['name'].iloc[0]
    description = prod_info[prod_info['gtin']==gtin]['description'].iloc[0]


    # Create full range df from creation date to today
    freq = 'D'
    end_date = '2020-04-05'
    t_df = pd.DataFrame(data=pd.date_range(start=created_at, end=end_date, freq=freq), columns=['date'])
    t_df['product_gtin'] = gtin

    ## ORDERS DATASET
    # Filter orders dataset
    t_orders = orders[orders['product_gtin']==gtin][['purchase_timestamp','product_gtin', 'price','freight_value', 'commission_product_olist','commission_freight_olist']].copy()

    # ADD ARTIFICIAL COLUMN WITH THE NUMBER OF ORDERS -> WILL BE USED TO COUNT THE ORDERS BY HOUR
    t_orders['orders'] = 1


    # GROUPS ORDERS BY CHOSEN FREQUENCY
    t_orders = t_orders.groupby([pd.Grouper(key='purchase_timestamp', freq=freq),'product_gtin'])\
                      .agg({'price':'mean', 
                            'freight_value':'mean',
                            'commission_product_olist':'mean',
                            'commission_freight_olist':'mean',
                            'orders':'sum'}).reset_index()

    # MERGE
    t_df = pd.merge(t_df, t_orders, how='left', left_on='date', right_on='purchase_timestamp')
    t_df.drop('purchase_timestamp', axis=1, inplace=True)
    
    t_df['product_gtin'] = gtin

    ## COMPETITION DATASET
    # FILTER GTIN
    t_competition = competition[competition['gtin'] == gtin].copy()
    # Exclude 0 values
    t_competition = t_competition[t_competition['value']>0]
    # filter competition on extremely low and high prices
    std = t_competition['value'].std()
    mean = t_competition['value'].mean()
    t_competition = t_competition[(t_competition['value']>= mean-3*std) & (t_competition['value']<= mean+3*std)]

    # Group by freq and get minimum value
    t_competition = t_competition.groupby([pd.Grouper(key='updated_at', freq=freq),'gtin']).min()[['value']].reset_index()

    # Merge datasets
    t_df = pd.merge(t_df, t_competition,
             left_on=['date','product_gtin'], right_on=['updated_at', 'gtin'],
             how='left')

    t_df.rename(columns={'value':'competition_price'}, inplace=True)

    t_df = t_df[['date', 'product_gtin', 'competition_price', 'price', 'freight_value',
           'commission_product_olist', 'commission_freight_olist', 'orders']].copy()

    t_df['competition_price'].fillna(method='ffill', inplace=True)
    t_df['competition_price'].fillna(method='bfill', inplace=True)




    # PRODUCT TYPE DATASET
    t_product_type = product_type[product_type['value']==gtin].copy()

    t_df = pd.merge(left=t_df, right=t_product_type,
             left_on='product_gtin', right_on='value', how='left')[['date', 'product_gtin', 'competition_price',
                                                        'price', 'freight_value', 'commission_product_olist', 
                                                        'commission_freight_olist', 'orders','product_type', 
                                                        'product_type_group']]

    # HISTORY DATASET
    t_history = history[history['gtin']==gtin].copy()

    # filter zero and outlier values
    t_history = t_history[t_history['offer'] > 0].copy()
    std = t_history['offer'].std()
    mean = t_history['offer'].mean()

    t_history = t_history[(t_history['offer']>= mean-3*std) & (t_history['offer']<= mean+3*std)]

    t_history = t_history.groupby([pd.Grouper(key='updated_at', freq='D'), 'gtin'])\
                             .agg({'stock':['max', 'min', 'mean'], 
                                   'price':['max', 'min', 'mean'],
                                   'offer':['max', 'min', 'mean']}).reset_index()

    t_history.columns = t_history.columns.droplevel(0)

    t_history.columns = ['date', 'product_gtin',
                       'stock_max', 'stock_min', 'stock_avg',
                       'price_max','price_min','price_avg',
                       'offer_max','offer_min','offer_avg']

    t_df = pd.merge(left=t_df, right=t_history,
                      left_on=['date', 'product_gtin'], right_on=['date', 'product_gtin'],
                      how='left')

    # forward fill agg measures then backfill
    t_df[['stock_max', 'stock_min',
           'stock_avg', 'price_max', 'price_min', 'price_avg', 'offer_max',
           'offer_min', 'offer_avg']] = t_df[['stock_max', 'stock_min',
                                                'stock_avg', 'price_max', 'price_min', 'price_avg', 'offer_max',
                                                'offer_min', 'offer_avg']]\
                                                .fillna(method='pad')\
                                                .fillna(method='bfill')

    t_df['name'] = name
    t_df['description'] = description
    
    t_df['orders'].fillna(value=0,inplace=True)
    t_df.loc[t_df["price"].isnull(),'price'] = t_df["offer_avg"]
    
    return t_df

# %%
len(gtins)
# Out:
# 698

# %%
prods = pd.read_csv('data/products.csv', dtype={'gtin':'str'})
dfs = []
failed = []
gtins = prods.gtin.unique().tolist()

for gtin in gtins:
    try:
        t_df = etl_function(gtin, orders, prod_info, product_type, competition, history)
        dfs.append(t_df)
    except:
        print(gtin)
        failed.append(gtin)
# Out:
# 40232931314
# 639853916499
# 606034863491
# 70896842121
# 732094204209
# 606529194192
# 695977684652
# 793574682894
# 20714170486
# 85000010587
# 751320753359
# 603922842064
# 606529089313
# 631384908165
# 606529884864
# 200000097790
# 650728044215
# 735810185448
# 751320234186
# 10450015189
# 27242868854
# 669818570800
# 40232926778
# 7426844271162
# 720355985363
# 40094936601
# 735810138666
# 669818571548
# 78000804690
# 76950450370
# 92756008973
# 669818568524
# 748323522587
# 602168928082
# 45496590017
# 603786426219
# 656879891258
# 656871234121
# 695937550119
# 769493100382
# 2960000075355
# 85854241793
# 639853121220
# 82184046791
# 34264495326
# 889698364676
# 742186937359
# 653437599090
# 86800097679
# 73228106052
# 49694508997
# 2960000359806
# 671072038248
# 700083859563

# %%
len(dfs)
# Out:
# 644

# %%
len(failed)
# Out:
# 54

# %%
df = pd.concat(dfs)

# %%
df[df['product_gtin']=='7890201094952']
# Out:
#           date   product_gtin  competition_price   price  freight_value  \
# 0   2019-08-07  7890201094952             119.00  119.00            NaN
# 1   2019-08-08  7890201094952             119.00  119.00            NaN
# 2   2019-08-09  7890201094952             119.00  119.00            NaN
# 3   2019-08-10  7890201094952             119.00  119.00            NaN
# 4   2019-08-11  7890201094952             119.00  119.00            NaN
# 5   2019-08-12  7890201094952             119.00  119.00            NaN
# 6   2019-08-13  7890201094952             119.00  119.00            NaN
# 7   2019-08-14  7890201094952             119.00  119.00            NaN
# 8   2019-08-15  7890201094952             119.00  119.00            NaN
# 9   2019-08-16  7890201094952             119.00  119.00            NaN
# 10  2019-08-17  7890201094952             119.00  119.00            NaN
# 11  2019-08-18  7890201094952             119.00  119.00            NaN
# 12  2019-08-19  7890201094952             119.00  119.00            NaN
# 13  2019-08-20  7890201094952             119.00  119.00            NaN
# 14  2019-08-21  7890201094952             119.00  119.00            NaN
# 15  2019-08-22  7890201094952             119.00  119.00            NaN
# 16  2019-08-23  7890201094952             119.00  119.00            NaN
# 17  2019-08-24  7890201094952             119.00  119.00            NaN
# 18  2019-08-25  7890201094952             119.00  119.00            NaN
# 19  2019-08-26  7890201094952             119.00  119.00            NaN
# 20  2019-08-27  7890201094952             119.00  119.00            NaN
# 21  2019-08-28  7890201094952             119.00  119.00          63.77
# 22  2019-08-29  7890201094952             119.00  119.00          26.57
# 23  2019-08-30  7890201094952             119.00  119.00          63.76
# 24  2019-08-31  7890201094952             119.00  119.00            NaN
# 25  2019-09-01  7890201094952             119.00  119.00            NaN
# 26  2019-09-02  7890201094952             119.00  119.00            NaN
# 27  2019-09-03  7890201094952             119.00  119.00          31.18
# 28  2019-09-04  7890201094952             119.00  119.00          69.31
# 29  2019-09-05  7890201094952             119.00  119.00            NaN
# ..         ...            ...                ...     ...            ...
# 213 2020-03-07  7890201094952             126.95  137.99            NaN
# 214 2020-03-08  7890201094952             126.95  137.99            NaN
# 215 2020-03-09  7890201094952             126.95  137.99            NaN
# 216 2020-03-10  7890201094952             126.95  137.99            NaN
# 217 2020-03-11  7890201094952             126.95  137.99            NaN
# 218 2020-03-12  7890201094952             126.95  137.99            NaN
# 219 2020-03-13  7890201094952             126.95  137.99            NaN
# 220 2020-03-14  7890201094952             126.95  137.99            NaN
# 221 2020-03-15  7890201094952             126.95  137.99            NaN
# 222 2020-03-16  7890201094952             126.95  137.99            NaN
# 223 2020-03-17  7890201094952             126.95  137.99            NaN
# 224 2020-03-18  7890201094952             126.95  137.99            NaN
# 225 2020-03-19  7890201094952             126.95  137.99            NaN
# 226 2020-03-20  7890201094952             126.95  137.99            NaN
# 227 2020-03-21  7890201094952             126.95  137.99            NaN
# 228 2020-03-22  7890201094952             126.95  137.99            NaN
# 229 2020-03-23  7890201094952             126.95  137.99            NaN
# 230 2020-03-24  7890201094952             126.95  137.99            NaN
# 231 2020-03-25  7890201094952             126.95  137.99            NaN
# 232 2020-03-26  7890201094952             126.95  137.99            NaN
# 233 2020-03-27  7890201094952             126.95  137.99            NaN
# 234 2020-03-28  7890201094952             126.95  137.99            NaN
# 235 2020-03-29  7890201094952             126.95  137.99            NaN
# 236 2020-03-30  7890201094952             126.95  137.99            NaN
# 237 2020-03-31  7890201094952             126.95  137.99            NaN
# 238 2020-04-01  7890201094952             126.95  137.99            NaN
# 239 2020-04-02  7890201094952             126.95  137.99            NaN
# 240 2020-04-03  7890201094952             126.95  137.99            NaN
# 241 2020-04-04  7890201094952             126.95  137.99            NaN
# 242 2020-04-05  7890201094952             126.95  137.99            NaN
#
#      commission_product_olist  commission_freight_olist  orders product_type  \
# 0                         NaN                       NaN     0.0          NaN
# 1                         NaN                       NaN     0.0          NaN
# 2                         NaN                       NaN     0.0          NaN
# 3                         NaN                       NaN     0.0          NaN
# 4                         NaN                       NaN     0.0          NaN
# 5                         NaN                       NaN     0.0          NaN
# 6                         NaN                       NaN     0.0          NaN
# 7                         NaN                       NaN     0.0          NaN
# 8                         NaN                       NaN     0.0          NaN
# 9                         NaN                       NaN     0.0          NaN
# 10                        NaN                       NaN     0.0          NaN
# 11                        NaN                       NaN     0.0          NaN
# 12                        NaN                       NaN     0.0          NaN
# 13                        NaN                       NaN     0.0          NaN
# 14                        NaN                       NaN     0.0          NaN
# 15                        NaN                       NaN     0.0          NaN
# 16                        NaN                       NaN     0.0          NaN
# 17                        NaN                       NaN     0.0          NaN
# 18                        NaN                       NaN     0.0          NaN
# 19                        NaN                       NaN     0.0          NaN
# 20                        NaN                       NaN     0.0          NaN
# 21                       0.19                      0.19     1.0          NaN
# 22                       0.19                      0.19     1.0          NaN
# 23                       0.19                      0.19     1.0          NaN
# 24                        NaN                       NaN     0.0          NaN
# 25                        NaN                       NaN     0.0          NaN
# 26                        NaN                       NaN     0.0          NaN
# 27                       0.19                      0.19     1.0          NaN
# 28                       0.19                      0.19     2.0          NaN
# 29                        NaN                       NaN     0.0          NaN
# ..                        ...                       ...     ...          ...
# 213                       NaN                       NaN     0.0          NaN
# 214                       NaN                       NaN     0.0          NaN
# 215                       NaN                       NaN     0.0          NaN
# 216                       NaN                       NaN     0.0          NaN
# 217                       NaN                       NaN     0.0          NaN
# 218                       NaN                       NaN     0.0          NaN
# 219                       NaN                       NaN     0.0          NaN
# 220                       NaN                       NaN     0.0          NaN
# 221                       NaN                       NaN     0.0          NaN
# 222                       NaN                       NaN     0.0          NaN
# 223                       NaN                       NaN     0.0          NaN
# 224                       NaN                       NaN     0.0          NaN
# 225                       NaN                       NaN     0.0          NaN
# 226                       NaN                       NaN     0.0          NaN
# 227                       NaN                       NaN     0.0          NaN
# 228                       NaN                       NaN     0.0          NaN
# 229                       NaN                       NaN     0.0          NaN
# 230                       NaN                       NaN     0.0          NaN
# 231                       NaN                       NaN     0.0          NaN
# 232                       NaN                       NaN     0.0          NaN
# 233                       NaN                       NaN     0.0          NaN
# 234                       NaN                       NaN     0.0          NaN
# 235                       NaN                       NaN     0.0          NaN
# 236                       NaN                       NaN     0.0          NaN
# 237                       NaN                       NaN     0.0          NaN
# 238                       NaN                       NaN     0.0          NaN
# 239                       NaN                       NaN     0.0          NaN
# 240                       NaN                       NaN     0.0          NaN
# 241                       NaN                       NaN     0.0          NaN
# 242                       NaN                       NaN     0.0          NaN
#
#     product_type_group  stock_max  stock_min   stock_avg  price_max  \
# 0                  NaN        5.0        5.0    5.000000     119.00
# 1                  NaN        5.0        5.0    5.000000     119.00
# 2                  NaN        5.0        5.0    5.000000     119.00
# 3                  NaN        5.0        5.0    5.000000     119.00
# 4                  NaN        5.0        5.0    5.000000     119.00
# 5                  NaN        5.0        5.0    5.000000     119.00
# 6                  NaN        5.0        5.0    5.000000     119.00
# 7                  NaN     1000.0        5.0  154.250000     119.00
# 8                  NaN        5.0        5.0    5.000000     119.00
# 9                  NaN     1000.0        5.0  336.666667     119.00
# 10                 NaN     1000.0        5.0  336.666667     119.00
# 11                 NaN     1000.0        5.0  336.666667     119.00
# 12                 NaN     1000.0        5.0  336.666667     119.00
# 13                 NaN     1000.0        0.0  272.692308     119.00
# 14                 NaN     1000.0        5.0  336.666667     119.00
# 15                 NaN     1000.0        5.0  336.666667     119.00
# 16                 NaN     1000.0        5.0  336.666667     119.00
# 17                 NaN     1000.0        5.0  336.666667     119.00
# 18                 NaN     1000.0        5.0  336.666667     119.00
# 19                 NaN     1000.0        5.0  336.666667     119.00
# 20                 NaN     1000.0        5.0  336.666667     119.00
# 21                 NaN      999.0      999.0  999.000000     119.00
# 22                 NaN      999.0      999.0  999.000000     119.00
# 23                 NaN      998.0      998.0  998.000000     119.00
# 24                 NaN      997.0      997.0  997.000000     119.00
# 25                 NaN      997.0      997.0  997.000000     119.00
# 26                 NaN      997.0      997.0  997.000000     119.00
# 27                 NaN      996.0      996.0  996.000000     119.00
# 28                 NaN      995.0      994.0  994.500000     119.00
# 29                 NaN      995.0      994.0  994.500000     119.00
# ..                 ...        ...        ...         ...        ...
# 213                NaN       49.0       49.0   49.000000     159.99
# 214                NaN       49.0       49.0   49.000000     159.99
# 215                NaN       49.0       49.0   49.000000     159.99
# 216                NaN       49.0       49.0   49.000000     159.99
# 217                NaN       49.0       49.0   49.000000     159.99
# 218                NaN       49.0       49.0   49.000000     159.99
# 219                NaN       49.0       49.0   49.000000     159.99
# 220                NaN       49.0       49.0   49.000000     159.99
# 221                NaN       49.0       49.0   49.000000     159.99
# 222                NaN       49.0       49.0   49.000000     159.99
# 223                NaN       49.0       49.0   49.000000     159.99
# 224                NaN       49.0       49.0   49.000000     159.99
# 225                NaN       49.0       49.0   49.000000     159.99
# 226                NaN       49.0       49.0   49.000000     159.99
# 227                NaN       49.0       49.0   49.000000     159.99
# 228                NaN       49.0       49.0   49.000000     159.99
# 229                NaN       49.0       49.0   49.000000     159.99
# 230                NaN       49.0       49.0   49.000000     159.99
# 231                NaN       49.0       49.0   49.000000     159.99
# 232                NaN       49.0       49.0   49.000000     159.99
# 233                NaN       49.0       49.0   49.000000     159.99
# 234                NaN       49.0       49.0   49.000000     159.99
# 235                NaN       49.0       49.0   49.000000     159.99
# 236                NaN       49.0       49.0   49.000000     159.99
# 237                NaN       49.0       49.0   49.000000     159.99
# 238                NaN       49.0       49.0   49.000000     159.99
# 239                NaN       49.0       49.0   49.000000     159.99
# 240                NaN       49.0       49.0   49.000000     159.99
# 241                NaN       49.0       49.0   49.000000     159.99
# 242                NaN       49.0       49.0   49.000000     159.99
#
#      price_min  price_avg  offer_max  offer_min  offer_avg  \
# 0       119.00     119.00     119.00     119.00     119.00
# 1       119.00     119.00     119.00     119.00     119.00
# 2       119.00     119.00     119.00     119.00     119.00
# 3       119.00     119.00     119.00     119.00     119.00
# 4       119.00     119.00     119.00     119.00     119.00
# 5       119.00     119.00     119.00     119.00     119.00
# 6       119.00     119.00     119.00     119.00     119.00
# 7       119.00     119.00     119.00     119.00     119.00
# 8       119.00     119.00     119.00     119.00     119.00
# 9       119.00     119.00     119.00     119.00     119.00
# 10      119.00     119.00     119.00     119.00     119.00
# 11      119.00     119.00     119.00     119.00     119.00
# 12      119.00     119.00     119.00     119.00     119.00
# 13      119.00     119.00     119.00     119.00     119.00
# 14      119.00     119.00     119.00     119.00     119.00
# 15      119.00     119.00     119.00     119.00     119.00
# 16      119.00     119.00     119.00     119.00     119.00
# 17      119.00     119.00     119.00     119.00     119.00
# 18      119.00     119.00     119.00     119.00     119.00
# 19      119.00     119.00     119.00     119.00     119.00
# 20      119.00     119.00     119.00     119.00     119.00
# 21      119.00     119.00     119.00     119.00     119.00
# 22      119.00     119.00     119.00     119.00     119.00
# 23      119.00     119.00     119.00     119.00     119.00
# 24      119.00     119.00     119.00     119.00     119.00
# 25      119.00     119.00     119.00     119.00     119.00
# 26      119.00     119.00     119.00     119.00     119.00
# 27      119.00     119.00     119.00     119.00     119.00
# 28      119.00     119.00     119.00     119.00     119.00
# 29      119.00     119.00     119.00     119.00     119.00
# ..         ...        ...        ...        ...        ...
# 213     137.99     155.59     137.99     137.99     137.99
# 214     137.99     155.59     137.99     137.99     137.99
# 215     137.99     155.59     137.99     137.99     137.99
# 216     137.99     155.59     137.99     137.99     137.99
# 217     137.99     155.59     137.99     137.99     137.99
# 218     137.99     155.59     137.99     137.99     137.99
# 219     137.99     155.59     137.99     137.99     137.99
# 220     137.99     155.59     137.99     137.99     137.99
# 221     137.99     155.59     137.99     137.99     137.99
# 222     137.99     155.59     137.99     137.99     137.99
# 223     137.99     155.59     137.99     137.99     137.99
# 224     137.99     155.59     137.99     137.99     137.99
# 225     137.99     155.59     137.99     137.99     137.99
# 226     137.99     155.59     137.99     137.99     137.99
# 227     137.99     155.59     137.99     137.99     137.99
# 228     137.99     155.59     137.99     137.99     137.99
# 229     137.99     155.59     137.99     137.99     137.99
# 230     137.99     155.59     137.99     137.99     137.99
# 231     137.99     155.59     137.99     137.99     137.99
# 232     137.99     155.59     137.99     137.99     137.99
# 233     137.99     155.59     137.99     137.99     137.99
# 234     137.99     155.59     137.99     137.99     137.99
# 235     137.99     155.59     137.99     137.99     137.99
# 236     137.99     155.59     137.99     137.99     137.99
# 237     137.99     155.59     137.99     137.99     137.99
# 238     137.99     155.59     137.99     137.99     137.99
# 239     137.99     155.59     137.99     137.99     137.99
# 240     137.99     155.59     137.99     137.99     137.99
# 241     137.99     155.59     137.99     137.99     137.99
# 242     137.99     155.59     137.99     137.99     137.99
#
#                                                   name  \
# 0    Kit Berço Americano Trança Menino 11 Peças Nuv...
# 1    Kit Berço Americano Trança Menino 11 Peças Nuv...
# 2    Kit Berço Americano Trança Menino 11 Peças Nuv...
# 3    Kit Berço Americano Trança Menino 11 Peças Nuv...
# 4    Kit Berço Americano Trança Menino 11 Peças Nuv...
# 5    Kit Berço Americano Trança Menino 11 Peças Nuv...
# 6    Kit Berço Americano Trança Menino 11 Peças Nuv...
# 7    Kit Berço Americano Trança Menino 11 Peças Nuv...
# 8    Kit Berço Americano Trança Menino 11 Peças Nuv...
# 9    Kit Berço Americano Trança Menino 11 Peças Nuv...
# 10   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 11   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 12   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 13   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 14   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 15   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 16   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 17   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 18   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 19   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 20   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 21   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 22   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 23   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 24   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 25   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 26   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 27   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 28   Kit Berço Americano Trança Menino 11 Peças Nuv...
# 29   Kit Berço Americano Trança Menino 11 Peças Nuv...
# ..                                                 ...
# 213  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 214  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 215  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 216  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 217  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 218  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 219  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 220  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 221  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 222  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 223  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 224  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 225  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 226  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 227  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 228  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 229  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 230  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 231  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 232  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 233  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 234  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 235  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 236  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 237  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 238  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 239  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 240  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 241  Kit Berço Americano Trança Menino 11 Peças Nuv...
# 242  Kit Berço Americano Trança Menino 11 Peças Nuv...
#
#                                            description
# 0    TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 1    TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 2    TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 3    TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 4    TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 5    TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 6    TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 7    TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 8    TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 9    TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 10   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 11   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 12   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 13   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 14   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 15   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 16   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 17   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 18   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 19   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 20   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 21   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 22   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 23   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 24   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 25   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 26   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 27   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 28   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 29   TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# ..                                                 ...
# 213  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 214  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 215  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 216  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 217  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 218  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 219  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 220  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 221  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 222  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 223  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 224  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 225  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 226  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 227  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 228  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 229  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 230  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 231  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 232  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 233  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 234  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 235  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 236  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 237  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 238  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 239  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 240  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 241  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
# 242  TOTAL 11 PEÇAS\n\n1 Cabeceira-----------------...
#
# [243 rows x 21 columns]

# %%
df.to_csv('data/timeseries644.csv', index=False)

# %% [markdown]
# ### OLD APPROACH

# %% [markdown]
# ### Dataframe with complete range
#
# Let's start by creating a dataframe with every data point we want to measure. It will contain hourly intervals, equally spaced between two dates.
# You can change the parameters in the cell below:

# %%
freq = 'D' # 'H' is for hourly data. You can use 'D' for days, 'W' for last day of week, 'Q' for quarter, etc.

start_date = '1/1/2017' # MM/DD/YYYY
end_date = '4/5/2020' # MM/DD/YYYY

# %%
df = pd.DataFrame(data=pd.date_range(start=start_date, end=end_date, freq=freq),
                  columns=['date'])

df.head(2)

# %%
df.tail(2)

# %% [markdown]
# ### Orders dataset
#
# Let's investigate our first dataset "orders.csv". It contains information for every sale that was executed in a given period of time.
# Our main idea is to aggregate sales data and merge it with our dates dataframe (df).

# %%
# READING ORDERS DATA AND TRANSFORMING COLUMNS
orders = pd.read_csv('data/orders.csv', dtype={'product_gtin':'str','origin_zip':'str',
                                               'destination_zip':'str'})

orders['purchase_timestamp'] = pd.to_datetime(orders['purchase_timestamp'])

# %%
orders.head()

# %%
orders.product_gtin.nunique()

# %% [markdown]
# ###### Selecting specific product
#
# In the orders dataset, we have sales information for 647 different products.
# For simplification purposes, let's choose one single product for analysis and manipulation of the dataset.
# To do so, choose a single gtin (str) in the cell below.
#
# - gtin = '7908243600137'
# - product_sku = 'PRD41RHHBF9NQR74'
# - canonical_sku = 'PRDIM5XOLWMUM0HU'

# %%
filter_orders = orders[['purchase_timestamp','product_gtin',
                        'price','freight_value',
                        'commission_product_olist','commission_freight_olist']].copy()

# ADD ARTIFICIAL COLUMN WITH THE NUMBER OF ORDERS -> WILL BE USED TO COUNT THE ORDERS BY HOUR
filter_orders['orders'] = 1


# GROUPS ORDERS BY CHOSEN FREQUENCY
filter_orders = filter_orders.groupby([pd.Grouper(key='purchase_timestamp', freq=freq),'product_gtin'])\
                  .agg({'price':'mean', 
                        'freight_value':'mean',
                        'commission_product_olist':'mean',
                        'commission_freight_olist':'mean',
                        'orders':'sum'}).reset_index()

# %%
filter_orders.head()

# %% [markdown]
# ##### merge date_range dataframe and orders
#
# Now that we have the number of sales of a given product by hour, along with its average price, average shipping values and average commissions (percentage), we can join with our date range dataframe.
#
# The 'NaN' rows are the ones that did not have any sales.

# %%
# MERGE DF and Filter orders

merged = pd.merge(df, filter_orders, how='left', left_on='date', right_on='purchase_timestamp')
merged.drop('purchase_timestamp', axis=1, inplace=True)

# %%
merged.head()

# %%
# Checking some rows with sales

merged[merged['orders'].notnull()].head()

# %% [markdown]
# ### Product_info dataset
#
# Another available dataset is the "product_info.csv". We will use it to check when a product was created in our database to fine tune the starting point of our time series.

# %%
prod_info = pd.read_csv('data/product_info.csv', dtype={'gtin':'str'})

prod_info['created_at'] = pd.to_datetime(prod_info['created_at'])

# %%
filter_prod = prod_info[['created_at','gtin','name']]

# %%
filter_prod = filter_prod.groupby(['gtin','name']).min().reset_index()

# %%
def truncate_date(x):
    return datetime.date(x.year,x.month,x.day)

# %%
filter_prod['created_date'] = filter_prod['created_at'].map(truncate_date)

# %%
filter_prod.head()

# %% [markdown]
# ##### Filter merged based on creation date

# %%
merged = pd.merge(merged, filter_prod, left_on='product_gtin', right_on='gtin', how='left')

# %%
merged['created_date'] = pd.to_datetime(merged['created_date'])

# %%
# Keep dates only where the product existed.
#merged = merged[merged['date']>=merged['created_date']].copy()

# %%
merged.head()

# %% [markdown]
# ### Competition
#
# Now, let's get our competitor's prices by the same frequency.

# %%
# Read data and format it
competition = pd.read_csv('data/competition.csv', dtype={'gtin':'str'})

competition['updated_at'] = pd.to_datetime(competition['updated_at'])

# %%
competition.head()

# %%
# filter out zero values
competition = competition[competition['value'] > 0]

# %%
gr = competition.groupby('gtin').agg({'value':['mean', 'std']}).reset_index()

# %%
gr.head()

# %%
comp_m = pd.merge(competition, gr, left_on='gtin', right_on='gtin')

# %%
comp_m.columns = ['updated_at', 'gtin', 'value', 'slug', 'mean','std']

# %%
comp_m['upper'] = comp_m['mean'].values + 3*comp_m['std'].values
comp_m['lower'] = comp_m['mean'].values - 3*comp_m['std'].values

# %%
comp_m.head()

# %%
comp_m.shape

# %%
# filter comp_m on extremely low and high prices
comp_m = comp_m[(comp_m['value']>= comp_m['lower']) & (comp_m['value']<= comp_m['upper'])]

# %%
comp_m.shape

# %%
# Group by freq and get minimum value
comp_m = comp_m.groupby([pd.Grouper(key='updated_at', freq=freq),'gtin']).min()[['value']].reset_index()

# %%
comp_m.head()

# %% [markdown]
# ##### merge competition prices with merged dataframe

# %%
#merged['day'] = merged['date'].apply(lambda x: x.date())

# %%
merged = pd.merge(merged, comp_m,
         left_on=['date','product_gtin'], right_on=['updated_at', 'gtin'],
         how='left')

merged.rename(columns={'value':'competition_price'}, inplace=True)

merged = merged[['date', 'product_gtin',  'competition_price', 'price', 'freight_value',
       'commission_product_olist', 'commission_freight_olist', 'orders']].copy()

# %%
merged.head()

# %%
merged[merged['orders']==0]

# %%
merged.sort_values(by=['product_gtin', 'date'])

# %% [markdown]
# We will forward fill the competition price.

# %%
merged['competition_price'].fillna(method='ffill', inplace=True)

# %%
merged.head()

# %%
merged.tail()

# %% [markdown]
# ### Product type and group
#
# Let's gather some information about the type of the analyzed product.
#
# This particular gtin belongs to the product_type "Kit para cabelo" (Hair Care Kit).
# The product belongs to the broader group "beleza_saude" (beauty_health)

# %%
product_type = pd.read_csv('data/product_type.csv', dtype={'value':str})

product_type.head()

product_type[product_type['value']==gtin]

merged.columns

merged = pd.merge(left=merged, right=product_type,
         left_on='product_gtin', right_on='value')[['date', 'product_gtin', 'competition_price',
                                                    'price', 'freight_value', 'commission_product_olist', 
                                                    'commission_freight_olist', 'orders','product_type', 
                                                    'product_type_group']]

# %%
merged.head()

# %% [markdown]
# ### Olist history of prices
# ### TODO
#
# For this particular case, we will only read historical data for the selected gtin. This will be changed once olist can share data on other products.
# Due to internal issues, the price history could not be gathered.

# %%
# history = pd.read_csv('data/product_history.csv', dtype={'gtin':str})
# history['updated_at'] = pd.to_datetime(history['updated_at'])

# %% [markdown]
# ### SOME CHARTS

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)

# %%
merged.columns

# %%
trace0 = go.Scatter(x=merged.date,
                   y=merged.orders, mode='lines')

trace1 = go.Scatter(x=merged.date,
                    y=merged.competition_price, mode='markers')

trace2 = go.Scatter(x=merged.date,
                    y=merged.price,
                    mode='markers')

trace3 = go.Scatter(x=merged.date,
                    y=merged.freight_value,
                    mode='lines')


iplot([trace0, trace1, trace2, trace3])

# %%
plt.figure(figsize=(12,8))

plt.style.use('fivethirtyeight')

sns.lineplot(x='date', y='orders', data=merged)
sns.scatterplot(x='date', y='competition_price', data=merged, label='competitor')
sns.scatterplot(x='date', y='price', data=merged, label='olist')

plt.legend()

plt.tight_layout()
plt.show()

# %%
sum(merged['orders'])
