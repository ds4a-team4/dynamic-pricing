# %%
import pandas as pd
import s3fs
import boto3
import numpy as np
from io import StringIO

# %%
_BUCKET_NAME = 'bsa-correlation-one'
_PREFIX = 'electronics/'
product_group = _PREFIX.replace('/','')

client = boto3.client('s3', aws_access_key_id='',
                            aws_secret_access_key='')

def ListFiles(client):
    """List files in specific S3 URL"""
    response = client.list_objects(Bucket=_BUCKET_NAME, Prefix=_PREFIX)
    for content in response.get('Contents', []):
        yield content.get('Key')

file_list = ListFiles(client)
product_types = []
for file in file_list:
    try:
        f = file.split(_PREFIX)[-1]
        if len(f.split('_')) == 3:
            types.append(f.split('_')[1])
    except:
        pass
    
product_types = list(dict.fromkeys(types))

# %% [markdown]
# ### Process Type functions

# %%
def read_orders(client, product_group, product_type):
    bucket = 'bsa-correlation-one'
    object_key = product_group + "/" + product_group + "_" +product_type + "_orders.csv"

    csv_obj = client.get_object(Bucket=bucket, Key=object_key)
    body = csv_obj['Body']
    csv_string = body.read().decode('utf-8')

    
    orders = pd.read_csv(StringIO(csv_string), dtype={'seller_item_gtin':'str'})
    
    orders = orders[['gmv', 'revenue', 'cogs', 'gross_profit',
       'channel_slug', 'channel_store', 'olist_order_purchase_timestamp',
       'olist_order_status',
       'olist_order_estimated_delivery_date',
       'olist_order_estimated_delivery_shift',
       'olist_order_total_discount',
       'olist_item_sku',
       'olist_item_full_name', 'olist_item_quantity',
       'olist_item_price', 'carrier', 'olist_item_freight_value',
       'olist_item_freight_mode',
       'seller_item_product_sku', 'seller_item_price',
       'seller_item_gtin',
       'seller_item_product_attributes',
       'seller_item_freight_value',
       'seller_item_commission_freight_olist',
       'seller_item_commission_product_olist',
       'seller_item_price_freight_shift',
       'seller_item_price_discount', 'seller_item_enable_subsidy']].copy() 

    orders['olist_order_purchase_timestamp'] = pd.to_datetime(orders.olist_order_purchase_timestamp)

    orders = orders.groupby([pd.Grouper(key='olist_order_purchase_timestamp', freq='D'),
                                 'seller_item_gtin', 'olist_item_full_name', 'seller_item_enable_subsidy']).sum()\
                        .sort_values(by=['seller_item_gtin', 'olist_order_purchase_timestamp']).reset_index()

    for column in ['olist_order_total_discount', 'olist_item_price', 'olist_item_freight_value',
           'seller_item_price', 'seller_item_freight_value',
           'seller_item_commission_freight_olist',
           'seller_item_commission_product_olist',
           'seller_item_price_freight_shift', 'seller_item_price_discount']:
    
        orders[column] = orders[column].values / orders['olist_item_quantity'].values
        
    orders.columns = ['purchase_timestamp', 'gtin', 'item_name',
                  'enable_subsidy', 'gmv', 'revenue', 'cogs', 'gross_profit',
                  'total_discount', 'orders', 'olist_price',
                  'freight_value', 'seller_item_price', 'seller_item_freight_value',
                  'commission_freight', 'commission_product', 
                  'price_freight_shift', 'price_discount']

    orders.drop(columns=['seller_item_price', 'seller_item_freight_value'], inplace=True)
    
    return orders


def read_competition(client, product_group, product_type):
    bucket = 'bsa-correlation-one'
    object_key = product_group + '/competition_' + product_group + '.csv'

    csv_obj = client.get_object(Bucket=bucket, Key=object_key)
    body = csv_obj['Body']
    csv_string = body.read().decode('utf-8')

    competition = pd.read_csv(StringIO(csv_string), dtype={'gtin':'str'})

    competition['updated_at'] = pd.to_datetime(competition.updated_at)

    competition.drop(columns=['Unnamed: 0'], inplace=True)
    
    return competition


def read_history(client, product_group, product_type):
    bucket = 'bsa-correlation-one'
    object_key = product_group + "/" + product_group+"_" + product_type + "_history.csv"

    csv_obj = client.get_object(Bucket=bucket, Key=object_key)
    body = csv_obj['Body']
    csv_string = body.read().decode('utf-8')

    history = pd.read_csv(StringIO(csv_string), lineterminator='\n', dtype={'gtin':'str'})

    history['updated_at'] = pd.to_datetime(history['updated_at'])
    
    return history


def process_gtin(gtin, orders, competition, history):
    temp_orders = orders[orders['gtin']==gtin].copy()
    temp_competition = competition[competition['gtin']==gtin].copy()
    temp_history = history[(history['gtin']==gtin) & (history['status']=='published')].copy()
    # Get first date and create range dataframe
    created_at = temp_history.updated_at.min()
    df = pd.DataFrame(data=pd.date_range(start=created_at.date(), end='2020-04-20', freq='D'),
                      columns=['date'])
    
    return temp_orders, temp_competition, temp_history, df


def process_competition(temp_competition, df):
    ### Competition
    # filter competition on extremely low and high prices
    std = temp_competition['value'].std()
    mean = temp_competition['value'].mean()
    temp_competition = temp_competition[(temp_competition['value']>= mean-3*std)
                                        & (temp_competition['value']<= mean+3*std)]

    # Group by freq and get minimum value
    temp_competition = temp_competition.groupby([pd.Grouper(key='updated_at', freq='D'),'gtin']).min()[['value']].reset_index()
    temp_competition['updated_at'] = temp_competition.updated_at.apply(lambda x: x.date())
    temp_competition['updated_at'] = pd.to_datetime(temp_competition.updated_at)
    temp_competition.rename(columns={'value':'competition_price'}, inplace=True)

    ### Clean df competition
    df = pd.merge(left=df, right=temp_competition,
                  left_on='date', right_on='updated_at', how='left')

    df.drop(columns=['updated_at','gtin'], inplace=True)

    df['competition_price'] = df['competition_price'].fillna(method='pad')#.fillna(method='bfill')
    
    return df


def process_orders(temp_orders, df):
    # Orders

    df = pd.merge(left=df, right=temp_orders,
                  left_on='date', right_on='purchase_timestamp', how='left')

    df.drop(columns=['purchase_timestamp'], inplace=True)
    
    return df


def process_history(temp_history, df):
    ### History
    # filter zero and outlier values
    temp_history = temp_history[temp_history['offer'] > 0].copy()
    std = temp_history['offer'].std()
    mean = temp_history['offer'].mean()
    temp_history = temp_history[(temp_history['offer']>= mean-3*std) & (temp_history['offer']<= mean+3*std)]
    temp_history = temp_history.groupby([pd.Grouper(key='updated_at', freq='D')])\
                               .agg({'stock':['max', 'min', 'mean'], 
                                     'price':['max', 'min', 'mean'],
                                     'offer':['max', 'min', 'mean']}).reset_index()

    temp_history.columns = temp_history.columns.droplevel(0)

    temp_history.columns = ['date',
                            'stock_max', 'stock_min', 'stock_avg',
                            'price_max','price_min','price_avg',
                            'offer_max','offer_min','offer_avg']

    temp_history = temp_history.fillna(method='pad').fillna(method='bfill')
    
    df = pd.merge(left=df, right=temp_history, left_on='date', right_on='date')
    
    return df


def adjustments(df):
    df['gtin'] = gtin
    df['item_name'] = df['item_name'].fillna(method='pad').fillna(method='bfill')

    df[['gmv','revenue','cogs','gross_profit','orders']] = df[['gmv','revenue','cogs','gross_profit','orders']].fillna(value=0)

    df.loc[df["olist_price"].isnull(),'olist_price'] = df["offer_avg"]
    
    return df

def save_type(master, product_group, product_type):
    fs = s3fs.S3FileSystem(anon=False, key='', secret='')
    bytes_to_write = master.to_csv(None).encode()
    with fs.open('s3://bsa-correlation-one/{}/{}_data.csv'.format(product_group, product_type), 'wb') as f:
        f.write(bytes_to_write)
        
        
def save_group(full_df, product_group):
    fs = s3fs.S3FileSystem(anon=False, key='', secret='')
    bytes_to_write = full_df.to_csv(None).encode()
    with fs.open('s3://bsa-correlation-one/{}_data.csv'.format(product_group), 'wb') as f:
        f.write(bytes_to_write)

# %%
product_types[:5]
# Out:
# ['Adaptador eletrônico',
#  'Alto-falante',
#  'Amplificador de linha',
#  'Amplificador de potência',
#  'Amplificador']

# %%
product_group
# Out:
# 'electronics'

# %%
total_types = len(product_types)
processed_types = 0
masters = []
for j, product_type in enumerate(product_types):
    print('-'*72)
    print("PRODUCT TYPE: {}\t {}/{}".format(product_type,j+1, total_types))

    try:
        orders = read_orders(client, product_group, product_type)
        competition = read_competition(client, product_group, product_type)
        history = read_history(client, product_group, product_type)
    except:
        continue
    
    if (orders.shape[0] > 0):
        gtins = list(set(orders.gtin))

        dfs = []
        success = 0
        failed = 0
        total = len(gtins)
        for i, gtin in enumerate(gtins):
            try:
                temp_orders, temp_competition, temp_history, df = process_gtin(gtin, orders, competition, history)
                try:
                    df = process_competition(temp_competition, df)
                except:
                    df['competition_price'] = np.nan
                df = process_orders(temp_orders, df)
                df = process_history(temp_history, df)
                df = adjustments(df)

                dfs.append(df)
                success += 1

                if (success+failed) % 50 == 0:
                    print("Success: {}\tFailed: {}\tProcessed: {}\tTotal: {}".format(success, failed, success+failed, total))
            except Exception as e:
                failed += 1
                if (success+failed) % 50 == 0:
                    print("Success: {}\tFailed: {}\tProcessed: {}\tTotal: {}".format(success, failed, success+failed, total))


    print("Success: {}\tFailed: {}\tProcessed: {}\tTotal: {}".format(success, failed, success+failed, total))

    
    try:
        master = pd.concat(dfs)
        master['product_type'] = product_type

        masters.append(master)

        save_type(master, product_group, product_type)
    except Exception as e:
        print(e)
    
full_df = pd.concat(masters)
full_df['product_group'] = product_group

save_group(full_df,product_group)
# Out:
# ------------------------------------------------------------------------
# PRODUCT TYPE: Adaptador eletrônico	 1/107
# Success: 50	Failed: 0	Processed: 50	Total: 324
# Success: 100	Failed: 0	Processed: 100	Total: 324
# Success: 149	Failed: 1	Processed: 150	Total: 324
# Success: 199	Failed: 1	Processed: 200	Total: 324
# Success: 249	Failed: 1	Processed: 250	Total: 324
# Success: 298	Failed: 2	Processed: 300	Total: 324
# Success: 322	Failed: 2	Processed: 324	Total: 324
# ------------------------------------------------------------------------
# PRODUCT TYPE: Alto-falante	 2/107
# Success: 50	Failed: 0	Processed: 50	Total: 245
# Success: 100	Failed: 0	Processed: 100	Total: 245
# Success: 150	Failed: 0	Processed: 150	Total: 245
# Success: 199	Failed: 1	Processed: 200	Total: 245
# Success: 243	Failed: 2	Processed: 245	Total: 245
# ------------------------------------------------------------------------
# PRODUCT TYPE: Amplificador de linha	 3/107
# Success: 1	Failed: 0	Processed: 1	Total: 1
# ------------------------------------------------------------------------
# PRODUCT TYPE: Amplificador de potência	 4/107
# Success: 1	Failed: 0	Processed: 1	Total: 1
# ------------------------------------------------------------------------
# PRODUCT TYPE: Amplificador	 5/107
# Success: 50	Failed: 0	Processed: 50	Total: 119
# Success: 99	Failed: 1	Processed: 100	Total: 119
# Success: 118	Failed: 1	Processed: 119	Total: 119
# ------------------------------------------------------------------------
# PRODUCT TYPE: Antena	 6/107
# Success: 50	Failed: 0	Processed: 50	Total: 163
# Success: 100	Failed: 0	Processed: 100	Total: 163
# Success: 150	Failed: 0	Processed: 150	Total: 163
# Success: 163	Failed: 0	Processed: 163	Total: 163
# ------------------------------------------------------------------------
# PRODUCT TYPE: Bateria para celular	 7/107
# Success: 47	Failed: 3	Processed: 50	Total: 316
# Success: 90	Failed: 10	Processed: 100	Total: 316
# Success: 136	Failed: 14	Processed: 150	Total: 316
# Success: 183	Failed: 17	Processed: 200	Total: 316
# Success: 231	Failed: 19	Processed: 250	Total: 316
# Success: 277	Failed: 23	Processed: 300	Total: 316
# Success: 292	Failed: 24	Processed: 316	Total: 316
# ------------------------------------------------------------------------
# PRODUCT TYPE: Bateria para câmera	 8/107
# Success: 24	Failed: 0	Processed: 24	Total: 24
# ------------------------------------------------------------------------
# PRODUCT TYPE: Bateria para eletrônicos	 9/107
# Success: 49	Failed: 1	Processed: 50	Total: 53
# Success: 52	Failed: 1	Processed: 53	Total: 53
# ------------------------------------------------------------------------
# PRODUCT TYPE: Bateria para filmadora	 10/107
# Success: 2	Failed: 0	Processed: 2	Total: 2
# ------------------------------------------------------------------------
# PRODUCT TYPE: Bateria para notebook	 11/107
# Success: 49	Failed: 1	Processed: 50	Total: 86
# Success: 84	Failed: 2	Processed: 86	Total: 86
# ------------------------------------------------------------------------
# PRODUCT TYPE: Bateria para telefone	 12/107
# Success: 18	Failed: 0	Processed: 18	Total: 18
# ------------------------------------------------------------------------
# PRODUCT TYPE: Bateria recarregável para controle	 13/107
# Success: 19	Failed: 0	Processed: 19	Total: 19
# ------------------------------------------------------------------------
# PRODUCT TYPE: Blu-ray player	 14/107
# Success: 19	Failed: 0	Processed: 19	Total: 19
# ------------------------------------------------------------------------
# PRODUCT TYPE: Booster	 15/107
# Success: 1	Failed: 0	Processed: 1	Total: 1
# ------------------------------------------------------------------------
# PRODUCT TYPE: Botoeira de sobrepor	 16/107
# Success: 1	Failed: 0	Processed: 1	Total: 1
# ------------------------------------------------------------------------
# PRODUCT TYPE: Botoeira liga e desliga	 17/107
# Success: 7	Failed: 0	Processed: 7	Total: 7
# ------------------------------------------------------------------------
# PRODUCT TYPE: Cabo de força	 18/107
# Success: 28	Failed: 0	Processed: 28	Total: 28
# ------------------------------------------------------------------------
# PRODUCT TYPE: Cabos de áudio e vídeo	 19/107
# Success: 16	Failed: 0	Processed: 16	Total: 16
# ------------------------------------------------------------------------
# PRODUCT TYPE: Caixa acústica	 20/107
# Success: 38	Failed: 0	Processed: 38	Total: 38
# ------------------------------------------------------------------------
# PRODUCT TYPE: Caixa de som	 21/107
# Success: 50	Failed: 0	Processed: 50	Total: 660
# Success: 99	Failed: 1	Processed: 100	Total: 660
# Success: 148	Failed: 2	Processed: 150	Total: 660
# Success: 198	Failed: 2	Processed: 200	Total: 660
# Success: 246	Failed: 4	Processed: 250	Total: 660
# Success: 294	Failed: 6	Processed: 300	Total: 660
# Success: 344	Failed: 6	Processed: 350	Total: 660
# Success: 394	Failed: 6	Processed: 400	Total: 660
# Success: 444	Failed: 6	Processed: 450	Total: 660
# Success: 494	Failed: 6	Processed: 500	Total: 660
# Success: 544	Failed: 6	Processed: 550	Total: 660
# Success: 594	Failed: 6	Processed: 600	Total: 660
# Success: 644	Failed: 6	Processed: 650	Total: 660
# Success: 653	Failed: 7	Processed: 660	Total: 660
# ------------------------------------------------------------------------
# PRODUCT TYPE: Capa para controle	 22/107
# Success: 2	Failed: 0	Processed: 2	Total: 2
# ------------------------------------------------------------------------
# PRODUCT TYPE: Capa para fone de ouvido	 23/107
# Success: 10	Failed: 0	Processed: 10	Total: 10
# ------------------------------------------------------------------------
# PRODUCT TYPE: Capa para smartwatch	 24/107
# Success: 4	Failed: 0	Processed: 4	Total: 4
# ------------------------------------------------------------------------
# PRODUCT TYPE: Capacitor	 25/107
# Success: 49	Failed: 1	Processed: 50	Total: 81
# Success: 80	Failed: 1	Processed: 81	Total: 81
# ------------------------------------------------------------------------
# PRODUCT TYPE: Celular	 26/107
# Success: 49	Failed: 1	Processed: 50	Total: 545
# Success: 98	Failed: 2	Processed: 100	Total: 545
# Success: 148	Failed: 2	Processed: 150	Total: 545
# Success: 198	Failed: 2	Processed: 200	Total: 545
# Success: 248	Failed: 2	Processed: 250	Total: 545
# Success: 297	Failed: 3	Processed: 300	Total: 545
# Success: 346	Failed: 4	Processed: 350	Total: 545
# Success: 395	Failed: 5	Processed: 400	Total: 545
# Success: 445	Failed: 5	Processed: 450	Total: 545
# Success: 494	Failed: 6	Processed: 500	Total: 545
# Success: 537	Failed: 8	Processed: 545	Total: 545
# ------------------------------------------------------------------------
# PRODUCT TYPE: Central telefônica	 27/107
# Success: 5	Failed: 0	Processed: 5	Total: 5
# ------------------------------------------------------------------------
# PRODUCT TYPE: Chaveador	 28/107
# Success: 18	Failed: 0	Processed: 18	Total: 18
# ------------------------------------------------------------------------
# PRODUCT TYPE: Chicote elétrico	 29/107
# Success: 13	Failed: 0	Processed: 13	Total: 13
# ------------------------------------------------------------------------
# PRODUCT TYPE: Ciclocomputador	 30/107
# Success: 18	Failed: 0	Processed: 18	Total: 18
# ------------------------------------------------------------------------
# PRODUCT TYPE: Coletor de dados	 31/107
# Success: 1	Failed: 0	Processed: 1	Total: 1
# ------------------------------------------------------------------------
# PRODUCT TYPE: Componente	 32/107
# Success: 8	Failed: 0	Processed: 8	Total: 8
# ------------------------------------------------------------------------
# PRODUCT TYPE: Controle remoto	 33/107
# Success: 49	Failed: 1	Processed: 50	Total: 822
# Success: 99	Failed: 1	Processed: 100	Total: 822
# Success: 149	Failed: 1	Processed: 150	Total: 822
# Success: 198	Failed: 2	Processed: 200	Total: 822
# Success: 248	Failed: 2	Processed: 250	Total: 822
# Success: 298	Failed: 2	Processed: 300	Total: 822
# Success: 347	Failed: 3	Processed: 350	Total: 822
# Success: 396	Failed: 4	Processed: 400	Total: 822
# Success: 444	Failed: 6	Processed: 450	Total: 822
# Success: 494	Failed: 6	Processed: 500	Total: 822
# Success: 543	Failed: 7	Processed: 550	Total: 822
# Success: 593	Failed: 7	Processed: 600	Total: 822
# Success: 643	Failed: 7	Processed: 650	Total: 822
# Success: 693	Failed: 7	Processed: 700	Total: 822
# Success: 743	Failed: 7	Processed: 750	Total: 822
# Success: 792	Failed: 8	Processed: 800	Total: 822
# Success: 814	Failed: 8	Processed: 822	Total: 822
# ------------------------------------------------------------------------
# PRODUCT TYPE: Conversor digital	 34/107
# Success: 49	Failed: 1	Processed: 50	Total: 63
# Success: 62	Failed: 1	Processed: 63	Total: 63
# ------------------------------------------------------------------------
# PRODUCT TYPE: Conversor hdmi	 35/107
# Success: 8	Failed: 1	Processed: 9	Total: 9
# ------------------------------------------------------------------------
# PRODUCT TYPE: Conversor musical	 36/107
# ------------------------------------------------------------------------
# PRODUCT TYPE: Câmera de segurança	 37/107
# Success: 49	Failed: 1	Processed: 50	Total: 388
# Success: 99	Failed: 1	Processed: 100	Total: 388
# Success: 149	Failed: 1	Processed: 150	Total: 388
# Success: 198	Failed: 2	Processed: 200	Total: 388
# Success: 247	Failed: 3	Processed: 250	Total: 388
# Success: 297	Failed: 3	Processed: 300	Total: 388
# Success: 345	Failed: 5	Processed: 350	Total: 388
# Success: 383	Failed: 5	Processed: 388	Total: 388
# ------------------------------------------------------------------------
# PRODUCT TYPE: Câmera digital	 38/107
# Success: 50	Failed: 0	Processed: 50	Total: 75
# Success: 75	Failed: 0	Processed: 75	Total: 75
# ------------------------------------------------------------------------
# PRODUCT TYPE: Câmera para celular	 39/107
# Success: 43	Failed: 0	Processed: 43	Total: 43
# ------------------------------------------------------------------------
# PRODUCT TYPE: Despertador	 40/107
# Success: 50	Failed: 0	Processed: 50	Total: 141
# Success: 100	Failed: 0	Processed: 100	Total: 141
# Success: 141	Failed: 0	Processed: 141	Total: 141
# ------------------------------------------------------------------------
# PRODUCT TYPE: Dispositivo de streaming	 41/107
# Success: 38	Failed: 0	Processed: 38	Total: 38
# ------------------------------------------------------------------------
# PRODUCT TYPE: Distribuidor de vídeo	 42/107
# Success: 1	Failed: 0	Processed: 1	Total: 1
# ------------------------------------------------------------------------
# PRODUCT TYPE: Divisor splitter	 43/107
# Success: 10	Failed: 0	Processed: 10	Total: 10
# ------------------------------------------------------------------------
# PRODUCT TYPE: Dock station	 44/107
# Success: 17	Failed: 0	Processed: 17	Total: 17
# ------------------------------------------------------------------------
# PRODUCT TYPE: Dvd player	 45/107
# Success: 17	Failed: 0	Processed: 17	Total: 17
# ------------------------------------------------------------------------
# PRODUCT TYPE: Espaguete termo retrátil	 46/107
# Success: 2	Failed: 0	Processed: 2	Total: 2
# ------------------------------------------------------------------------
# PRODUCT TYPE: Filmadora	 47/107
# Success: 22	Failed: 0	Processed: 22	Total: 22
# ------------------------------------------------------------------------
# PRODUCT TYPE: Fone de ouvido	 48/107
# Success: 49	Failed: 1	Processed: 50	Total: 1193
# Success: 97	Failed: 3	Processed: 100	Total: 1193
# Success: 147	Failed: 3	Processed: 150	Total: 1193
# Success: 197	Failed: 3	Processed: 200	Total: 1193
# Success: 247	Failed: 3	Processed: 250	Total: 1193
# Success: 297	Failed: 3	Processed: 300	Total: 1193
# Success: 345	Failed: 5	Processed: 350	Total: 1193
# Success: 393	Failed: 7	Processed: 400	Total: 1193
# Success: 443	Failed: 7	Processed: 450	Total: 1193
# Success: 493	Failed: 7	Processed: 500	Total: 1193
# Success: 543	Failed: 7	Processed: 550	Total: 1193
# Success: 593	Failed: 7	Processed: 600	Total: 1193
# Success: 643	Failed: 7	Processed: 650	Total: 1193
# Success: 692	Failed: 8	Processed: 700	Total: 1193
# Success: 741	Failed: 9	Processed: 750	Total: 1193
# Success: 791	Failed: 9	Processed: 800	Total: 1193
# Success: 841	Failed: 9	Processed: 850	Total: 1193
# Success: 890	Failed: 10	Processed: 900	Total: 1193
# Success: 939	Failed: 11	Processed: 950	Total: 1193
# Success: 987	Failed: 13	Processed: 1000	Total: 1193
# Success: 1037	Failed: 13	Processed: 1050	Total: 1193
# Success: 1086	Failed: 14	Processed: 1100	Total: 1193
# Success: 1134	Failed: 16	Processed: 1150	Total: 1193
# Success: 1176	Failed: 17	Processed: 1193	Total: 1193
# ------------------------------------------------------------------------
# PRODUCT TYPE: Fonte de alimentação	 49/107
# Success: 49	Failed: 1	Processed: 50	Total: 1039
# Success: 99	Failed: 1	Processed: 100	Total: 1039
# Success: 149	Failed: 1	Processed: 150	Total: 1039
# Success: 199	Failed: 1	Processed: 200	Total: 1039
# Success: 247	Failed: 3	Processed: 250	Total: 1039
# Success: 297	Failed: 3	Processed: 300	Total: 1039
# Success: 347	Failed: 3	Processed: 350	Total: 1039
# Success: 397	Failed: 3	Processed: 400	Total: 1039
# Success: 447	Failed: 3	Processed: 450	Total: 1039
# Success: 495	Failed: 5	Processed: 500	Total: 1039
# Success: 545	Failed: 5	Processed: 550	Total: 1039
# Success: 594	Failed: 6	Processed: 600	Total: 1039
# Success: 644	Failed: 6	Processed: 650	Total: 1039
# Success: 694	Failed: 6	Processed: 700	Total: 1039
# Success: 744	Failed: 6	Processed: 750	Total: 1039
# Success: 793	Failed: 7	Processed: 800	Total: 1039
# Success: 843	Failed: 7	Processed: 850	Total: 1039
# Success: 893	Failed: 7	Processed: 900	Total: 1039
# Success: 943	Failed: 7	Processed: 950	Total: 1039
# Success: 993	Failed: 7	Processed: 1000	Total: 1039
# Success: 1031	Failed: 8	Processed: 1039	Total: 1039
# ------------------------------------------------------------------------
# PRODUCT TYPE: Fonte de alimentação para telefone	 50/107
# Success: 3	Failed: 0	Processed: 3	Total: 3
# ------------------------------------------------------------------------
# PRODUCT TYPE: Globo para microfone	 51/107
# ------------------------------------------------------------------------
# PRODUCT TYPE: Gps	 52/107
# Success: 10	Failed: 0	Processed: 10	Total: 10
# ------------------------------------------------------------------------
# PRODUCT TYPE: Gravador	 53/107
# Success: 38	Failed: 1	Processed: 39	Total: 39
# ------------------------------------------------------------------------
# PRODUCT TYPE: Home theater	 54/107
# Success: 7	Failed: 1	Processed: 8	Total: 8
# ------------------------------------------------------------------------
# PRODUCT TYPE: Interface celular	 55/107
# Success: 2	Failed: 0	Processed: 2	Total: 2
# ------------------------------------------------------------------------
# PRODUCT TYPE: Interface de áudio	 56/107
# Success: 8	Failed: 0	Processed: 8	Total: 8
# ------------------------------------------------------------------------
# PRODUCT TYPE: Interfone	 57/107
# Success: 44	Failed: 2	Processed: 46	Total: 46
# ------------------------------------------------------------------------
# PRODUCT TYPE: Kit de telefones	 58/107
# Success: 4	Failed: 0	Processed: 4	Total: 4
# ------------------------------------------------------------------------
# PRODUCT TYPE: Kit tablet e acessórios	 59/107
# Success: 0	Failed: 1	Processed: 1	Total: 1
# No objects to concatenate
# ------------------------------------------------------------------------
# PRODUCT TYPE: Kit touch e display	 60/107
# Success: 10	Failed: 0	Processed: 10	Total: 10
# ------------------------------------------------------------------------
# PRODUCT TYPE: Leitor de códigos de barras	 61/107
# Success: 44	Failed: 0	Processed: 44	Total: 44
# ------------------------------------------------------------------------
# PRODUCT TYPE: Leitor e gravador de cd dvd	 62/107
# Success: 41	Failed: 0	Processed: 41	Total: 41
# ------------------------------------------------------------------------
# PRODUCT TYPE: Media player	 63/107
# Success: 34	Failed: 0	Processed: 34	Total: 34
# ------------------------------------------------------------------------
# PRODUCT TYPE: Mesa de som	 64/107
# Success: 49	Failed: 1	Processed: 50	Total: 94
# Success: 93	Failed: 1	Processed: 94	Total: 94
# ------------------------------------------------------------------------
# PRODUCT TYPE: Micro system	 65/107
# Success: 5	Failed: 0	Processed: 5	Total: 5
# ------------------------------------------------------------------------
# PRODUCT TYPE: Microfone	 66/107
# Success: 50	Failed: 0	Processed: 50	Total: 234
# Success: 99	Failed: 1	Processed: 100	Total: 234
# Success: 147	Failed: 3	Processed: 150	Total: 234
# Success: 196	Failed: 4	Processed: 200	Total: 234
# Success: 230	Failed: 4	Processed: 234	Total: 234
# ------------------------------------------------------------------------
# PRODUCT TYPE: Mini system	 67/107
# Success: 6	Failed: 0	Processed: 6	Total: 6
# ------------------------------------------------------------------------
# PRODUCT TYPE: Monitor de áudio	 68/107
# Success: 4	Failed: 0	Processed: 4	Total: 4
# ------------------------------------------------------------------------
# PRODUCT TYPE: Moving head	 69/107
# Success: 1	Failed: 0	Processed: 1	Total: 1
# ------------------------------------------------------------------------
# PRODUCT TYPE: Máquina de bolha de sabão	 70/107
# Success: 2	Failed: 0	Processed: 2	Total: 2
# ------------------------------------------------------------------------
# PRODUCT TYPE: Máquina para relógio	 71/107
# Success: 7	Failed: 0	Processed: 7	Total: 7
# ------------------------------------------------------------------------
# PRODUCT TYPE: Patch panel	 72/107
# Success: 8	Failed: 0	Processed: 8	Total: 8
# ------------------------------------------------------------------------
# PRODUCT TYPE: Pedestal para tv	 73/107
# Success: 1	Failed: 0	Processed: 1	Total: 1
# ------------------------------------------------------------------------
# PRODUCT TYPE: Placa circuito	 74/107
# Success: 50	Failed: 0	Processed: 50	Total: 92
# Success: 92	Failed: 0	Processed: 92	Total: 92
# ------------------------------------------------------------------------
# PRODUCT TYPE: Potenciômetro	 75/107
# Success: 14	Failed: 0	Processed: 14	Total: 14
# ------------------------------------------------------------------------
# PRODUCT TYPE: Pressostato	 76/107
# Success: 4	Failed: 1	Processed: 5	Total: 5
# ------------------------------------------------------------------------
# PRODUCT TYPE: Processador de efeitos	 77/107
# Success: 4	Failed: 1	Processed: 5	Total: 5
# ------------------------------------------------------------------------
# PRODUCT TYPE: Processador de áudio	 78/107
# Success: 2	Failed: 0	Processed: 2	Total: 2
# ------------------------------------------------------------------------
# PRODUCT TYPE: Projetor	 79/107
# Success: 14	Failed: 1	Processed: 15	Total: 15
# ------------------------------------------------------------------------
# PRODUCT TYPE: Pulseira usb	 80/107
# ------------------------------------------------------------------------
# PRODUCT TYPE: Ramal	 81/107
# Success: 9	Failed: 0	Processed: 9	Total: 9
# ------------------------------------------------------------------------
# PRODUCT TYPE: Rastreador	 82/107
# Success: 8	Failed: 0	Processed: 8	Total: 8
# ------------------------------------------------------------------------
# PRODUCT TYPE: Receiver	 83/107
# Success: 12	Failed: 0	Processed: 12	Total: 12
# ------------------------------------------------------------------------
# PRODUCT TYPE: Receptor	 84/107
# Success: 50	Failed: 0	Processed: 50	Total: 94
# Success: 93	Failed: 1	Processed: 94	Total: 94
# ------------------------------------------------------------------------
# PRODUCT TYPE: Relógio espião	 85/107
# Success: 13	Failed: 0	Processed: 13	Total: 13
# ------------------------------------------------------------------------
# PRODUCT TYPE: Rádio comunicador	 86/107
# Success: 18	Failed: 0	Processed: 18	Total: 18
# ------------------------------------------------------------------------
# PRODUCT TYPE: Rádio relógio	 87/107
# Success: 39	Failed: 0	Processed: 39	Total: 39
# ------------------------------------------------------------------------
# PRODUCT TYPE: Rádio	 88/107
# Success: 49	Failed: 1	Processed: 50	Total: 92
# Success: 89	Failed: 3	Processed: 92	Total: 92
# ------------------------------------------------------------------------
# PRODUCT TYPE: Smartwatch	 89/107
# Success: 50	Failed: 0	Processed: 50	Total: 291
# Success: 100	Failed: 0	Processed: 100	Total: 291
# Success: 150	Failed: 0	Processed: 150	Total: 291
# Success: 200	Failed: 0	Processed: 200	Total: 291
# Success: 250	Failed: 0	Processed: 250	Total: 291
# Success: 291	Failed: 0	Processed: 291	Total: 291
# ------------------------------------------------------------------------
# PRODUCT TYPE: Soundbar	 90/107
# Success: 5	Failed: 0	Processed: 5	Total: 5
# ------------------------------------------------------------------------
# PRODUCT TYPE: Strobo	 91/107
# Success: 1	Failed: 1	Processed: 2	Total: 2
# ------------------------------------------------------------------------
# PRODUCT TYPE: Subwoofer	 92/107
# Success: 24	Failed: 1	Processed: 25	Total: 25
# ------------------------------------------------------------------------
# PRODUCT TYPE: Suporte para dvd, blu-ray e dvr	 93/107
# ------------------------------------------------------------------------
# PRODUCT TYPE: Tampa traseira	 94/107
# Success: 38	Failed: 12	Processed: 50	Total: 131
# Success: 84	Failed: 16	Processed: 100	Total: 131
# Success: 111	Failed: 20	Processed: 131	Total: 131
# ------------------------------------------------------------------------
# PRODUCT TYPE: Tecla botão home para celular	 95/107
# Success: 14	Failed: 1	Processed: 15	Total: 15
# ------------------------------------------------------------------------
# PRODUCT TYPE: Tela de projeção	 96/107
# Success: 2	Failed: 0	Processed: 2	Total: 2
# ------------------------------------------------------------------------
# PRODUCT TYPE: Telefone headset	 97/107
# Success: 5	Failed: 0	Processed: 5	Total: 5
# ------------------------------------------------------------------------
# PRODUCT TYPE: Telefone	 98/107
# Success: 49	Failed: 1	Processed: 50	Total: 168
# Success: 98	Failed: 2	Processed: 100	Total: 168
# Success: 147	Failed: 3	Processed: 150	Total: 168
# Success: 165	Failed: 3	Processed: 168	Total: 168
# ------------------------------------------------------------------------
# PRODUCT TYPE: Terminal isolado	 99/107
# Success: 4	Failed: 0	Processed: 4	Total: 4
# ------------------------------------------------------------------------
# PRODUCT TYPE: Toca discos	 100/107
# Success: 10	Failed: 0	Processed: 10	Total: 10
# ------------------------------------------------------------------------
# PRODUCT TYPE: Transceiver	 101/107
# ------------------------------------------------------------------------
# PRODUCT TYPE: Transistor	 102/107
# Success: 7	Failed: 0	Processed: 7	Total: 7
# ------------------------------------------------------------------------
# PRODUCT TYPE: Trimpot	 103/107
# Success: 2	Failed: 0	Processed: 2	Total: 2
# ------------------------------------------------------------------------
# PRODUCT TYPE: Tv	 104/107
# Success: 49	Failed: 1	Processed: 50	Total: 150
# Success: 98	Failed: 2	Processed: 100	Total: 150
# Success: 148	Failed: 2	Processed: 150	Total: 150
# Success: 148	Failed: 2	Processed: 150	Total: 150
# ------------------------------------------------------------------------
# PRODUCT TYPE: Vitrola	 105/107
# Success: 8	Failed: 0	Processed: 8	Total: 8
# ------------------------------------------------------------------------
# PRODUCT TYPE: Voip	 106/107
# Success: 12	Failed: 0	Processed: 12	Total: 12
# ------------------------------------------------------------------------
# PRODUCT TYPE: Walkie talkie	 107/107
# Success: 14	Failed: 0	Processed: 14	Total: 14

# %%
full_df.shape
# Out:
# (3079658, 28)

# %%
full_df.product_type.nunique()
# Out:
# 101
